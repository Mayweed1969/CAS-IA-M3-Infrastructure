-- %%
SELECT PC.Name AS ProductCategory, P.Name AS ProductName, P.ProductNumber, P.ListPrice
FROM bronze.product AS P
INNER JOIN bronze.productcategory AS PC ON P.ProductCategoryID = PC.ProductCategoryID
