# %%
# %sql
/* Find the managed location under Catalog >> dbw_<name>_dataplatform_dev_001 >> Details >> Storage root*/
CREATE CATALOG IF NOT EXISTS alexandreMueller_lakehouse MANAGED LOCATION 'abfss://unity-catalog-storage@dbstorageai7c3e3fykkjo.dfs.core.windows.net/7405615455797822';
