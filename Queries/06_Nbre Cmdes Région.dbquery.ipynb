-- %%
SELECT a.StateProvince, COUNT(soh.SalesOrderID) AS nombre_commandes
FROM Address a
JOIN SalesOrderHeader soh ON a.AddressID = soh.BillToAddressID
GROUP BY a.StateProvince
ORDER BY a.StateProvince;
